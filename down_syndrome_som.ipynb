# %%
# %pip install holoviews hvplot -q
# # !cd /codespace/ && git clone https://github.com/ahsanMah/simpsom
# !cd /codespace/simpsom && python setup.py install --user

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'

# %%
import re
import holoviews as hv
from holoviews import opts
from holoviews import dim
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="fb2169e1-6c7c-4a03-9a6e-33913e19389c" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
import hvplot.pandas
import cupy
import simpsom as sps
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

from bokeh.plotting import figure, output_file, show
from bokeh.util.hex import axial_to_cartesian, cartesian_to_axial
from bokeh.transform import linear_cmap, factor_cmap, factor_mark, log_cmap, jitter
from bokeh.models import ColumnDataSource, CDSView, BooleanFilter, GroupFilter, IndexFilter, Legend
from bokeh.models import ColorBar, FixedTicker
from bokeh.palettes import Spectral5, Accent5, Spectral10
from collections import OrderedDict, Counter

import colorcet as cc
from colorcet.plotting import swatch, swatches
from bokeh.layouts import row, column

scale = lambda x,a,b: (b-a)*(x-min(x))/(max(x)-min(x)) + a  
mpl.rcParams['lines.markersize'] = 3

# %matplotlib inline

# %%
workdir = "/ASD/ahsan_projects/braintypicality/workdir/cuda_opt/learnable/eval/ckpt_1500002/smin=0.01_smax=0.80_t=20"
# %ls $workdir
# Out:
# abcd-test_ibis-hr-inlier_ibis-ds-sa-raw_results.npz
# abcd-train_abcd-val_lesion_load_20-enhanced_results.npz
# abcd-val_abcd-test_lesion_load_20_results.npz
# abcd-val_abcd-val_abcd-val-raw_results.npz
# ibis-inlier_ibis-atypical_ibis-asd-raw_results.npz
# ibis-inlier_ibis-atypical_ibis-asd_results.npz
# ibis-inlier_ibis-hr-inlier_ibis-ds-sa_results.npz

# %%
from sade.datasets.loaders import get_image_files_list
extract_id = lambda f: f.split("/")[-1].replace('.nii.gz', '')

dataset_dir = "/DATA/Users/amahmood/braintyp/processed_v2/"
splits_dir = "/ASD/ahsan_projects//braintypicality/dataset/dataset_split_builder/"

abcd_train_files = get_image_files_list("abcd-train", dataset_dir, splits_dir)
abcd_val_files = get_image_files_list("abcd-val", dataset_dir, splits_dir)
abcd_test_files = get_image_files_list("abcd-test", dataset_dir, splits_dir)

ibis_inlier_files = get_image_files_list("ibis-inlier", dataset_dir, splits_dir)
ibis_ds_files = get_image_files_list("ibis-ds-sa", dataset_dir, splits_dir)
ibis_hr_files = get_image_files_list("ibis-hr-inlier", dataset_dir, splits_dir)
ibis_atyp_files = get_image_files_list("ibis-atypical", dataset_dir, splits_dir)
ibis_asd_files = get_image_files_list("ibis-asd", dataset_dir, splits_dir)
# Out:
# 2024-09-19 20:32:08.600748: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-19 20:32:08.611557: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-19 20:32:08.624094: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-19 20:32:08.628006: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
def build_dataset(dataset_list, dataset_id_to_name):

    X_data = np.concatenate(dataset_list, axis=0)
    y_labels = np.concatenate([[i-1]*len(d) for i,d in enumerate(dataset_list)])
    assert len(y_labels)==len(X_data)

    mu, std = np.mean(X_data[y_labels <= 0], axis=0), np.std(X_data[y_labels <= 0], axis=0)
    X_data = (X_data - mu) / std

    train_data = X_data[y_labels <= 0]
    train_labels =  y_labels[y_labels <= 0]


    test_data = X_data[y_labels > 0]
    test_labels = y_labels[y_labels > 0]
    
    return (train_data, train_labels), (test_data, test_labels)

# %%
# NOT including training data in SOM tuning
score_file = np.load(f"{workdir}/abcd-train_abcd-val_lesion_load_20-enhanced_results.npz", allow_pickle=True)
abcd_train_data = np.concatenate([score_file[f] for f in ['eval_score_norms']], axis=0)

score_file = np.load(f"{workdir}/abcd-val_abcd-test_lesion_load_20_results.npz", allow_pickle=True)
abcd_data = np.concatenate([score_file[f] for f in ['eval_score_norms', 'inlier_score_norms']], axis=0)

## Loading IBIS score norms
score_file = np.load(f"{workdir}/ibis-inlier_ibis-hr-inlier_ibis-ds-sa_results.npz", allow_pickle=True)
ibis_typical = np.concatenate([score_file[f] for f in ['eval_score_norms']], axis=0)
ibis_hr_typical = score_file['inlier_score_norms']
ibis_ds = score_file['ood_score_norms']

score_file = np.load(f"{workdir}/ibis-inlier_ibis-atypical_ibis-asd_results.npz", allow_pickle=True)
# ibis_atypical = np.concatenate([ibis_atypical, score_file['inlier_score_norms']], axis=0)
ibis_atypical = score_file['inlier_score_norms']
ibis_asd = score_file['ood_score_norms']

ibis_typical.shape, ibis_atypical.shape, ibis_ds.shape
# Out:
# ((82, 20), (38, 20), (28, 20))

# %%
print("ABCD-to-IBIS ratio:", len(abcd_data) / len(ibis_typical))
# Out:
# ABCD-to-IBIS ratio: 4.024390243902439

# %%
dataset_id_to_name = {-1: "ABCD", 0:"LR-Typical", 1:"HR-Typical", 2:"Atypical", 3:"Down Syndrome", 4:"ASD"}
dataset_name_to_id = {v:k for k,v in dataset_id_to_name.items()}
dataset_list = [abcd_data, ibis_typical, ibis_hr_typical, ibis_atypical, ibis_ds, ibis_asd]

# abcd_data = np.concatenate([abcd_data, abcd_train_data])
dataset_list = [abcd_data, ibis_typical, ibis_hr_typical, ibis_atypical, ibis_ds, ibis_asd]
(train_data, train_labels), (test_data, test_labels) = build_dataset(dataset_list, dataset_id_to_name)
dssamples = test_data[test_labels == dataset_name_to_id["Down Syndrome"]]

train_data.shape,  test_data.shape, dssamples.shape
# Out:
# ((412, 20), (237, 20), (28, 20))

# %%
def build_bmu_df(net, test_data, test_labels):
    
    bmus_arr = net.find_bmu_ix(cupy.asarray(test_data)).get()
    bmu_dists = [np.linalg.norm(net.nodes_list[bmuidx].weights - x) for bmuidx,x in zip(bmus_arr, test_data)]

    bmus = pd.DataFrame([b.item() for b in bmus_arr], columns=["BMU"])
    bmus['dataset'] = [dataset_id_to_name[i] for i in test_labels]
    bmus['bmu-distance'] = bmu_dists
    bmu_df = bmus.set_index('BMU')

    for idx in bmu_df.index:
        node = net.nodes_list[idx]
        bmu_df.loc[idx, ['x', 'y']] = node.pos.get()
    
    bmucounts = bmus[['BMU', 'dataset']].groupby(['BMU']).value_counts().reset_index(level=-1, name='count')
    bmudists = bmus[['BMU', 'bmu-distance']].groupby(['BMU']).mean()
    bmudists_median = bmus[['BMU', 'bmu-distance']].groupby(['BMU']).median()
    
    for idx in bmucounts.index:
        node = net.nodes_list[idx]
        bmucounts.loc[idx, ['x', 'y']] = node.pos.get()
        bmucounts.loc[idx, 'neighbourhood-distance'] = node.difference
        bmucounts.loc[idx, 'mean-matching-distance'] = bmudists.loc[idx, 'bmu-distance']
        bmucounts.loc[idx, 'mean-matching-distance'] = bmudists.loc[idx, 'bmu-distance']
        

    significant_bmus = []
    dataset_counts = bmus['dataset'].value_counts()
    
    for name, g in bmucounts.groupby('dataset'):
        cohort_count = dataset_counts[name]
        min_cohort_count = int(0.1*cohort_count)
        significant_bmus.append(g[g['count'] >= int(0.1*cohort_count)])

    significant_bmus = pd.concat(significant_bmus).sort_values('count', ascending=False)
    
    return bmu_df, significant_bmus

# %%
def build_hexbin_source(net, train_data, bmu_df, significant_bmus):
    _x,_y = bmu_df.x, bmu_df.y
    _q,_r = cartesian_to_axial(_x,_y, size=HEXSIZE, orientation="pointytop", aspect_scale=1)
    _sx,_sy = axial_to_cartesian(_q,_r,  size=1, orientation="pointytop")

    scattersource = ColumnDataSource(dict(x= _sx, y=_sy, dataset=bmu_df['dataset'],
                                    color=[color_dict[d] for d in bmu_df['dataset']]
    ))
    
    bmu_density = net.find_bmu_ix(cupy.asarray(train_data)).get()
    bmu_density = Counter(bmu_density)
    
    x,y,distance, sample_count, density = [],[],[],[], []
    binned_density = []
    for idx, n in enumerate(net.nodes_list):
        x.append(n.pos[0].get())
        y.append(n.pos[1].get())
        distance.append(n.difference)
        c = bmu_density.get(idx, 1e-5)
        d = 100 * c / len(train_data)
        density.append(d)
        binned_density.append(np.ceil(d) if d > 1e-5 else 0)
        
        # add an average of matching distances? tain distances or test distances?
        
    # This defines the datapoints for the heatmap background
    x,y,distance = np.asarray(x),np.asarray(y),np.asarray(distance)
    q,r = cartesian_to_axial(x,y, size=HEXSIZE, orientation="pointytop")
    binsource = ColumnDataSource(dict(q=q,r=r, distance=distance,
                                      density=density, binned_density=binned_density))
    
    # This defines the source of the scatter plots of test samples
    # to be overlayed on the heatmap
    _x,_y = bmu_df.x, bmu_df.y
    _q,_r = cartesian_to_axial(_x,_y, size=HEXSIZE, orientation="pointytop", aspect_scale=1)
    sx, sy = axial_to_cartesian(_q,_r,  size=1, orientation="pointytop")
    scattersource = ColumnDataSource(dict(x= _sx, y=_sy, dataset=bmu_df['dataset'],
                                    color=[color_dict[d] for d in bmu_df['dataset']]
    ))
    
    # Optionally we can plot only the significant nodes (i.e nodes w/ >= 10% of the dataset)
    x = significant_bmus.x
    y = significant_bmus.y
    dataset = significant_bmus['dataset']
    count = significant_bmus['count']
    q,r = cartesian_to_axial(x,y, size=HEXSIZE, orientation="pointytop", aspect_scale=1)
    sx,sy = axial_to_cartesian(q,r,  size=1, orientation="pointytop")
    significantsource = ColumnDataSource(dict(x=sx,y=sy, dataset=dataset,
                                              color=[color_dict[d] for d in dataset],
                                              scale= scale(significant_bmus['count'], 10, 50)))
    
    return binsource, scattersource, significantsource

# %%
# Some plotting defaults

HEXSIZE = .99 / np.sqrt(3)
marker_dict = OrderedDict({"Down Syndrome":"triangle", "ASD":"star", "HR-Typical":"circle", "Atypical":"diamond"})
DATASETS = list(marker_dict.keys())
MARKERS = list(marker_dict.values())
color_dict = OrderedDict({"Down Syndrome":'#f03b20', #red
                          "HR-Typical":"#7fc97f", #green
                          "ASD":"#fdc076", #orange
                          "Atypical":"#fdc086", #blue
                         })

SCALE_FACTOR = 1
background_fill_color="#fafafa"
header_text_size = "18px"
MARKER_SIZE = 13

def plot_hex_heatmap(scattersource, binsource, heatmap_col='distance',
                     cmap_upper_ratio = 1.02, cmap_lower_ratio=1, 
                     width=800, height=700, cmap='Greys256', cbar_ticks=True, scatter_jitter=True):

    
#     group_filter = BooleanFilter([c != "LR-Typical" for c in bmusdf['dataset']])
#     view = CDSView(filter=group_filter)
    heatmap_min, heatmap_max = min(binsource.data[heatmap_col]), max(binsource.data[heatmap_col])
    
    
    plot = figure(width=int(width * SCALE_FACTOR), height=int(height * SCALE_FACTOR), background_fill_color=background_fill_color)
    r = plot.hex_tile(
        source=binsource, color="darkgray",
        fill_color=linear_cmap(heatmap_col, cmap,
                               low=cmap_lower_ratio*heatmap_min,
                               high=cmap_upper_ratio*heatmap_max),
        alpha=0.8
    )
    
    if cbar_ticks:
        cbar_font_size="12pt"
        cbar_tick_color='black'
    else:
        cbar_font_size="0pt"
        cbar_tick_color=None
    
    tick_values = np.arange(1,6)
    tick_offset = 0.04  # Adjust based on how much offset you need
    offset_tick_values = [tick + tick_offset for tick in tick_values]
    tick_labels = {k:str(int(k)) for k in offset_tick_values}
    
    
    color_bar = r.construct_color_bar(padding=1, title="Percentage of Typical Samples Matching Node",
                                      title_text_font_size=f"{18*SCALE_FACTOR}px",
                                     major_label_text_font_size=cbar_font_size,
                                     major_tick_line_color=cbar_tick_color,
                                    ticker=FixedTicker(ticks=offset_tick_values),
                                      major_tick_line_width=2,
                                     )
    color_bar.major_label_overrides = tick_labels
    plot.add_layout(color_bar, "right")

    plot.scatter(source=scattersource,
                 marker=factor_mark('dataset', MARKERS, DATASETS),
                 color='color',
                 x=jitter('x', .8) if scatter_jitter else 'x',
                 y=jitter('y', .8) if scatter_jitter else 'y',
                 size='scale' if 'scale' in scattersource.data else MARKER_SIZE*SCALE_FACTOR,
                 legend_group="dataset",
                 alpha=0.9,
                 line_color='black'
    )

    legend = Legend(
        items=plot.legend.items,
        location='top_right',
        orientation='horizontal',
        title='Dataset',
        title_text_font_size=f"{int(14*SCALE_FACTOR)}px",
        background_fill_color=background_fill_color,
        label_text_font_size=f"{int(13*SCALE_FACTOR)}px",
        glyph_height=int(32*SCALE_FACTOR),
        glyph_width=int(32*SCALE_FACTOR)
    )

    # Remove original legend
    plot.legend.destroy()
    plot.add_layout(legend, 'above')

    plot.axis.visible = False
    plot.grid.visible = False
    
    return plot

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=5).fit(train_data)
print(pca.explained_variance_ratio_, pca.explained_variance_ratio_[0]/pca.explained_variance_ratio_[1])

num_neurons = 5*np.sqrt(train_data.shape[0])
grid_size = int(np.ceil(np.sqrt(num_neurons)))

ratio = np.floor(pca.explained_variance_ratio_[0]/pca.explained_variance_ratio_[1])
h = np.ceil(np.sqrt(num_neurons / ratio))
w = h*ratio
print(f"Suggested minimum number of neurons: {int(num_neurons)}")
print(f"Suggested height and width: {int(h)}x{int(w)}")
# Out:
# [0.7799858  0.11797354 0.05953263 0.02628019 0.0075338 ] 6.6115313
# Suggested minimum number of neurons: 101
# Suggested height and width: 5x30

# %%
# %%time
som_height, som_width = 11, 11
net = sps.SOMNet(som_height, som_width, train_data, topology='hexagonal', 
                init='PCA', metric='euclidean',
                neighborhood_fun='gaussian', PBC=True,
                random_seed=42, GPU=True, CUML=False,
                output_path="/tmp/")

net.train(train_algo='batch', start_learning_rate=0.1, epochs=1000, batch_size=-1,
           early_stop='mapdiff', early_stop_tolerance=1e-5, early_stop_patience=10
)
net.plot_convergence(figsize=(11, 5), logy=True)
net.get_nodes_difference()
net.plot_map_by_difference(show=True, print_out=False)
# Out:
# 2024-09-19 20:32:10.231 | INFO     | simpsom.network:__init__:106 - Periodic Boundary Conditions active.
# 2024-09-19 20:32:10.246 | INFO     | simpsom.network:__init__:115 - Hexagonal topology.
# 2024-09-19 20:32:10.247 | WARNING  | simpsom.network:_set_weights:179 - Please make sure that the data have been standardized before using PCA.
# 2024-09-19 20:32:10.247 | INFO     | simpsom.network:_set_weights:181 - The weights will be initialized with PCA.
# 2024-09-19 20:32:10.340 | INFO     | simpsom.network:train:381 - The map will be trained with the batch algorithm.
# 2024-09-19 20:32:10.561 | INFO     | simpsom.network:train:403 - Early stop active.
# 2024-09-19 20:32:10.561 | WARNING  | simpsom.network:train:404 - Early stop is an experimental feature, make sure to know what you are doing!
# Early stop tolerance reached at epoch 985, training will be stopped.rk:train:492 -
# ...

# %%
net.plot_convergence(figsize=(11, 5), logy=False, )
# Out:
# 2024-09-19 20:32:19.875 | INFO     | simpsom.network:plot_convergence:803 - Convergence results will be saved to:
# /tmp/./som_convergence.png

# %% [markdown]
# ## Save SOM mappings for Down Syndrome samples
#
# This could be redone for other cohorts as well

# %%
bmus_arr = net.find_bmu_ix(cupy.asarray(dssamples)).get()
ibis_ds_IDs = [extract_id(f['image']) for f in ibis_ds_files]
df = pd.DataFrame({"bmu": bmus_arr, "ID": ibis_ds_IDs})
df.to_csv(f'data/ds_prototypes_{som_height}x{som_width}.csv', index=None)
df.head()
# Out:
#    bmu          ID
# 0   27  IBIS105477
# 1   27  IBIS110925
# 2   39  IBIS123451
# 3   27  IBIS146443
# 4   27  IBIS241887

# %%
bmu_df, significant_bmus = build_bmu_df(net, test_data, test_labels)
significant_bmus
# Out:
#            dataset  count    x         y  neighbourhood-distance  \
# BMU
# 27   Down Syndrome     16  2.5  4.330127                1.817074
# 57             ASD      8  5.0  1.732051                1.675460
# 52        Atypical      4  4.0  6.928203                1.515629
# 75        Atypical      4  6.5  7.794229                0.989307
# 69        Atypical      3  6.5  2.598076                1.152430
# 39   Down Syndrome      2  3.0  5.196152                1.583942
# 40   Down Syndrome      2  3.5  6.062178                1.743616
#
#      mean-matching-distance
# BMU
# 27                 5.786942
# 57                 2.250140
# 52                 0.935917
# 75                 1.239407
# 69                 2.396281
# 39                 1.324753
# 40                 1.229748

# %% [markdown]
# ### Experimental plot

# %%
x = significant_bmus.x
y = significant_bmus.y
dataset = significant_bmus['dataset']
count = significant_bmus['count']

q,r = cartesian_to_axial(x,y, size=HEXSIZE, orientation="pointytop", aspect_scale=1)
sx,sy = axial_to_cartesian(q,r,  size=1, orientation="pointytop")

hexsource = ColumnDataSource(dict(q=q,r=r, dataset=dataset,  scale=scale(count, 0.1, 1.1)))
scattersource = ColumnDataSource(dict(x=sx,y=sy, dataset=dataset, scale=count+10))
group_filter = BooleanFilter([c != "LR-Typical" for c in dataset])
view = CDSView(filter=group_filter)

# %%
plot = figure(width=450, height=400)
renderer = plot.hex_tile(
    source=hexsource, view=view,
    color=factor_cmap('dataset', 'Category10_7', DATASETS),
    scale='scale',
    legend_group="dataset"
)

plot.legend.location = "top_left"
plot.legend.orientation = "horizontal"
# plot.legend.title = "Dataset"
show(plot)
# Out:
#   <div id="f3b16edf-7fc0-4704-a140-4e18a9050431" data-root-id="p1013" style="display: contents;"></div>

# %%
binsource, scattersource, significantsource = build_hexbin_source(net, train_data, bmu_df, significant_bmus)

# %%
distance_plot = plot_hex_heatmap(scattersource, binsource, cbar_ticks=False)
score_norm_density_plot = plot_hex_heatmap(scattersource, binsource, heatmap_col='density', cmap=cc.fire, cbar_ticks=True)

# %%
p = row(score_norm_density_plot, distance_plot)
show(p)
# Out:
#   <div id="c1088988-d8e8-4774-8e5c-08a59fbc16ea" data-root-id="p1206" style="display: contents;"></div>

# %%
show(plot_hex_heatmap(significantsource, binsource, cbar_ticks=False, scatter_jitter=False))
# Out:
#   <div id="b66ee1a3-ce4b-46fc-8bb2-b58c08202bb1" data-root-id="p1212" style="display: contents;"></div>

# %% [markdown]
# # Lobe Score *Norms*
#
# The lobes are retrived by consolidating the AAL pacelation into lobes by an expert. Norms are computed over raw multi-scale score tensors.

# %%
data_path = "/ASD/ahsan_projects/braintypicality/workdir/cuda_opt/learnable/eval/heatmaps_v2/"
# %ls -ailh $data_path
# Out:
# total 4.7M
#  14509287652 drwxr-xr-x.  5 amahmood root 4.0K Mar 14  2024 ./
# 124554312778 drwxr-xr-x. 13 amahmood root 4.0K Sep  9 13:41 ../
#  21476853454 drwxr-xr-x.  2 amahmood root   46 Mar 14  2024 .ipynb_checkpoints/
# 124557784603 -rw-r--r--.  1 amahmood root 2.3K Mar 12  2024 aal_labels.csv
#  14509997592 -rw-r--r--.  1 amahmood root 4.3K Mar 14  2024 aal_labels_lobe.csv
#  14509997646 -rw-r--r--.  1 amahmood root 207K Mar 14  2024 abcd-test_lobe_score_norms.npz
#  14509997652 -rw-r--r--.  1 amahmood root 207K Mar 14  2024 abcd-val_lobe_score_norms.npz
#  14509287664 -rw-r--r--.  1 amahmood root 915K Mar 14  2024 ds_mean.nii.gz
#  14509997644 -rw-r--r--.  1 amahmood root  82K Mar 14  2024 ibis-asd_lobe_score_norms.npz
#  14509997642 -rw-r--r--.  1 amahmood root  48K Mar 14  2024 ibis-atypical_lobe_score_norms.npz
#  14509997650 -rw-r--r--.  1 amahmood root  36K Mar 14  2024 ibis-ds-sa_lobe_score_norms.npz
# ...

# %%
cohort_data = {"ibis-inlier":None, "ibis-hr-inlier":None, "abcd-val":None, "abcd-test":None,
               "ibis-atypical":None, "ibis-ds-sa":None, "ibis-asd":None}
for cohort in cohort_data.keys():
    fname = f"{data_path}/{cohort}_lobe_score_norms.npz"
    cohort_data[cohort] =  np.load(fname, allow_pickle=True)['arr_0']
    print(cohort, "->", cohort_data[cohort].shape)
# Out:
# ibis-inlier -> (82, 360)
# ibis-hr-inlier -> (106, 360)
# abcd-val -> (165, 360)
# abcd-test -> (165, 360)
# ibis-atypical -> (38, 360)
# ibis-ds-sa -> (28, 360)
# ibis-asd -> (65, 360)

# %%
abcd_data = np.concatenate((cohort_data['abcd-val'], cohort_data['abcd-test']))
dataset_list = [abcd_data, cohort_data['ibis-inlier'], cohort_data['ibis-hr-inlier'], cohort_data['ibis-atypical'], cohort_data['ibis-ds-sa'], cohort_data['ibis-asd']]
(train_data, train_labels), (test_data, test_labels) = build_dataset(dataset_list, dataset_id_to_name)
train_data.shape
# Out:
# (412, 360)

# %%
# %%time
som_height, som_width = 11, 11
net = sps.SOMNet(som_height, som_width, train_data, topology='hexagonal', 
                init='PCA', metric='euclidean',
                neighborhood_fun='gaussian', PBC=True,
                random_seed=42, GPU=True, CUML=False,
                output_path="/tmp/")

net.train(train_algo='batch', start_learning_rate=0.1, epochs=5000, batch_size=128,
           early_stop='mapdiff', early_stop_tolerance=1e-5, early_stop_patience=500
)
net.plot_convergence(figsize=(11, 5), logy=True)
net.get_nodes_difference()
net.plot_map_by_difference(show=True, print_out=False)
# Out:
# 2024-09-19 20:32:20.684 | INFO     | simpsom.network:__init__:106 - Periodic Boundary Conditions active.
# 2024-09-19 20:32:20.685 | INFO     | simpsom.network:__init__:115 - Hexagonal topology.
# 2024-09-19 20:32:20.685 | WARNING  | simpsom.network:_set_weights:179 - Please make sure that the data have been standardized before using PCA.
# 2024-09-19 20:32:20.686 | INFO     | simpsom.network:_set_weights:181 - The weights will be initialized with PCA.
# 2024-09-19 20:32:20.754 | INFO     | simpsom.network:train:381 - The map will be trained with the batch algorithm.
# 2024-09-19 20:32:20.758 | INFO     | simpsom.network:train:403 - Early stop active.
# 2024-09-19 20:32:20.759 | WARNING  | simpsom.network:train:404 - Early stop is an experimental feature, make sure to know what you are doing!
# 2024-09-19 20:34:11.462 | INFO     | simpsom.network:plot_convergence:803 - Convergence results will be saved to:
# /tmp/./som_convergence.png
# ...

# %%
bmu_df, significant_bmus = build_bmu_df(net, test_data, test_labels)
significant_bmus
# Out:
#            dataset  count    x         y  neighbourhood-distance  \
# BMU
# 94   Down Syndrome     15  8.0  5.196152                6.176378
# 27             ASD      6  2.5  4.330127                6.414917
# 17        Atypical      3  1.0  5.196152                7.218855
# 29        Atypical      3  2.5  6.062178                4.066339
# 51        Atypical      3  4.5  6.062178                4.696280
# 40        Atypical      3  3.5  6.062178                3.732184
# 52        Atypical      3  4.0  6.928203                4.290294
# 61        Atypical      3  5.0  5.196152                4.856057
# 84        Atypical      3  7.5  6.062178                7.426862
# 72   Down Syndrome      2  6.0  5.196152                7.120927
#
#      mean-matching-distance
# BMU
# 94                25.410780
# 27                12.484841
# 17                10.980166
# 29                 9.539160
# 51                10.297057
# 40                10.616667
# 52                11.425999
# ...

# %%
binsource, scattersource, significantsource = build_hexbin_source(net, train_data, bmu_df, significant_bmus)

# %%
distance_plot = plot_hex_heatmap(scattersource, binsource, cbar_ticks=False)
density_plot = plot_hex_heatmap(scattersource, binsource, heatmap_col='density', cmap=cc.fire, cbar_ticks=True)

# %%
p = row(density_plot, distance_plot)
show(p)
# Out:
#   <div id="af63b64c-a1de-40ad-89de-b29f59690664" data-root-id="p1422" style="display: contents;"></div>

# %%
show(plot_hex_heatmap(significantsource, binsource, cbar_ticks=False, scatter_jitter=False))
# Out:
#   <div id="e28ccbff-b370-48d9-882e-adcba11343dc" data-root-id="p1428" style="display: contents;"></div>

# %% [markdown]
# ## Voxel Mean of Score tensors
#
# As opposed to an L2-norm, we compute a voxel-wise mean of the score tensors.

# %%
data_path = '/ASD/ahsan_projects/braintypicality/workdir/cuda_opt/learnable/eval/ckpt_1500002/smin=0.01_smax=0.80_t=20/'
# %ls -ailh $data_path
# Out:
# total 38G
# 68749929763 drwxr-xr-x. 2 amahmood root 4.0K Mar 14  2024 ./
#  5471184352 drwxr-xr-x. 9 amahmood root 4.0K Mar  1  2024 ../
# 68832424508 -rw-r--r--. 1 amahmood root  18G Mar 14  2024 abcd-test_ibis-hr-inlier_ibis-ds-sa-raw_results.npz
# 68770761261 -rw-r--r--. 1 amahmood root 135K Mar  4  2024 abcd-train_abcd-val_lesion_load_20-enhanced_results.npz
# 68749929764 -rw-r--r--. 1 amahmood root  43K Mar  1  2024 abcd-val_abcd-test_lesion_load_20_results.npz
# 68832424516 -rw-r--r--. 1 amahmood root 9.7G Mar 14  2024 abcd-val_abcd-val_abcd-val-raw_results.npz
# 68832424506 -rw-r--r--. 1 amahmood root  11G Mar 14  2024 ibis-inlier_ibis-atypical_ibis-asd-raw_results.npz
# 68749929766 -rw-r--r--. 1 amahmood root  18K Mar  8  2024 ibis-inlier_ibis-atypical_ibis-asd_results.npz
# 68749929767 -rw-r--r--. 1 amahmood root  20K Mar  8  2024 ibis-inlier_ibis-hr-inlier_ibis-ds-sa_results.npz

# %%
# %%time
if not os.path.exists("data/voxel_means.npz"):

    voxel_score_means = {}

    # abcd-test_ibis-hr-inlier_ibis-ds-sa-raw_results
    data = np.load(f"{data_path}/abcd-test_ibis-hr-inlier_ibis-ds-sa-raw_results.npz", allow_pickle=True)
    avg = lambda x: np.abs(x).mean(axis=(2,3,4))
    
    voxel_score_means["abcd-test"] = avg(data["eval_score_norms"])
    voxel_score_means["ibis-hr-inlier"] = avg(data["inlier_score_norms"])
    voxel_score_means["ibis-ds"] = avg(data["ood_score_norms"])

    data = np.load(f"{data_path}/ibis-inlier_ibis-atypical_ibis-asd-raw_results.npz", allow_pickle=True)
    voxel_score_means["ibis-inlier"] = avg(data["eval_score_norms"])
    voxel_score_means["ibis-atypical"] = avg(data["inlier_score_norms"])
    voxel_score_means["ibis-asd"] = avg(data["ood_score_norms"])

    data = np.load(f"{data_path}/abcd-val_abcd-val_abcd-val-raw_results.npz", allow_pickle=True)
    voxel_score_means["abcd-val"] = avg(data["eval_score_norms"])

    np.savez_compressed(f"data/voxel_means.npz", **voxel_score_means)

else:
    voxel_score_means = np.load("data/voxel_means.npz", allow_pickle=True)
# Out:
# CPU times: user 577 µs, sys: 0 ns, total: 577 µs
# Wall time: 1.46 ms

# %%
voxel_score_means
# Out:
# NpzFile 'data/voxel_means.npz' with keys: abcd-test, ibis-hr-inlier, ibis-ds, ibis-inlier, ibis-atypical...

# %%
cohort_data = voxel_score_means
abcd_data = np.concatenate((cohort_data['abcd-val'], cohort_data['abcd-test']))
dataset_list = [abcd_data, cohort_data['ibis-inlier'], cohort_data['ibis-hr-inlier'],
                cohort_data['ibis-atypical'], cohort_data['ibis-ds'], cohort_data['ibis-asd']]
(train_data, train_labels), (test_data, test_labels) = build_dataset(dataset_list, dataset_id_to_name)
train_data.shape
# Out:
# (412, 20)

# %%
sns.histplot(abcd_data[:,::2])
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(abcd_data[:,::2])
# Out:
# <Axes: ylabel='Count'>

# %%
# %%time
som_height, som_width = 11, 11
net = sps.SOMNet(som_height, som_width, train_data, topology='hexagonal', 
                init='PCA', metric='euclidean',
                neighborhood_fun='gaussian', PBC=True,
                random_seed=42, GPU=True, CUML=False,
                output_path="/tmp/")

net.train(train_algo='batch', start_learning_rate=0.1, epochs=5000, batch_size=256,
           early_stop='mapdiff', early_stop_tolerance=1e-5, early_stop_patience=500
)
net.plot_convergence(figsize=(11, 5), logy=True)
net.get_nodes_difference()
net.plot_map_by_difference(show=True, print_out=False)
# Out:
# 2024-09-19 20:34:13.758 | INFO     | simpsom.network:__init__:106 - Periodic Boundary Conditions active.
# 2024-09-19 20:34:13.759 | INFO     | simpsom.network:__init__:115 - Hexagonal topology.
# 2024-09-19 20:34:13.759 | WARNING  | simpsom.network:_set_weights:179 - Please make sure that the data have been standardized before using PCA.
# 2024-09-19 20:34:13.759 | INFO     | simpsom.network:_set_weights:181 - The weights will be initialized with PCA.
# 2024-09-19 20:34:13.774 | INFO     | simpsom.network:train:381 - The map will be trained with the batch algorithm.
# 2024-09-19 20:34:13.775 | INFO     | simpsom.network:train:403 - Early stop active.
# 2024-09-19 20:34:13.775 | WARNING  | simpsom.network:train:404 - Early stop is an experimental feature, make sure to know what you are doing!
# 2024-09-19 20:35:15.891 | INFO     | simpsom.network:plot_convergence:803 - Convergence results will be saved to:
# /tmp/./som_convergence.png
# ...

# %%
bmu_df, significant_bmus = build_bmu_df(net, test_data, test_labels)
significant_bmus

binsource, scattersource, significantsource = build_hexbin_source(net, train_data, bmu_df, significant_bmus)

distance_plot = plot_hex_heatmap(scattersource, binsource, cbar_ticks=False)
voxel_mean_density_plot = plot_hex_heatmap(scattersource, binsource, heatmap_col='density', cmap=cc.fire, cbar_ticks=True)

p = row(voxel_mean_density_plot, distance_plot)
show(p)
# Out:
#   <div id="aade775d-b4c9-4ffc-8c1b-ec397dbf6b41" data-root-id="p1638" style="display: contents;"></div>

# %%
ds_bmu_df, ds_significant_bmus = build_bmu_df(net,test_data[test_labels==dataset_name_to_id['Down Syndrome']],
                                              test_labels[test_labels==dataset_name_to_id['Down Syndrome']])

# %%
sns.histplot(binsource.data['density'], bins=np.arange(0,6))
# Out:
# <Axes: ylabel='Count'>

# %%
color_dict["Down Syndrome"]="#ffff99"
# color_dict["Down Syndrome"]="yellow"

colors = ['#f1eef6','#feebe2','#fbb4b9','#f768a1','#c51b8a','#7a0177']
SCALE_FACTOR = 1
binsource, scattersource, significantsource = build_hexbin_source(net, train_data, ds_bmu_df, ds_significant_bmus)
ds_density_plot = plot_hex_heatmap(scattersource, binsource, heatmap_col='binned_density',
                                   cmap=colors[1:], cbar_ticks=True,
#                                    cmap_upper_ratio=1.1,
#                                    cmap_lower_ratio=0.9
                                  )
show(ds_density_plot)
# Out:
#   <div id="f11787af-969e-489f-a8d7-6e3741955ae1" data-root-id="p1656" style="display: contents;"></div>

# %%
colors = list(cc.blues)
# colors.reverse()
binsource, scattersource, significantsource = build_hexbin_source(net, train_data, ds_bmu_df, ds_significant_bmus)
ds_density_plot = plot_hex_heatmap(scattersource, binsource, heatmap_col='density',
                                   cmap=colors, cbar_ticks=True,
                                   cmap_upper_ratio=.95, cmap_lower_ratio=1.1e2)
show(ds_density_plot)
# Out:
#   <div id="a9661a39-8eb3-422a-bd22-831f4a64df82" data-root-id="p1735" style="display: contents;"></div>

# %%
warm_cmap = cc.coolwarm[128:]

binned_cmap = [warm_cmap[i] for i in np.linspace(0,len(warm_cmap), num=5, endpoint=False, dtype=int)]

# %%
from matplotlib.colors import to_hex
colormap = mpl.colormaps['Reds']

# Number of colors you want
n_colors = 256
# Get a list of colors
colors = [to_hex(colormap(i)) for i in np.linspace(0.01, 0.9, n_colors)]

# Display the colors
print(colors[:4])
# Out:
# ['#fff4ee', '#fff3ed', '#fff2ec', '#fff2eb']

# %%
binsource, scattersource, significantsource = build_hexbin_source(net, train_data, ds_bmu_df, ds_significant_bmus)
ds_density_plot = plot_hex_heatmap(scattersource, binsource, heatmap_col='density',
                                   cmap=warm_cmap, cbar_ticks=True,
                                   cmap_upper_ratio=0.99, cmap_lower_ratio=1)
show(ds_density_plot)
# Out:
#   <div id="c20883ad-f4df-4c85-9087-ddd228139a00" data-root-id="p1814" style="display: contents;"></div>

# %%
show(plot_hex_heatmap(significantsource, binsource, cbar_ticks=False, scatter_jitter=False))
# Out:
#   <div id="fa2e9e94-8afd-48dd-a49e-8c5279d3a6a0" data-root-id="p1881" style="display: contents;"></div>

# %%
p = column(voxel_mean_density_plot, score_norm_density_plot)
show(p)
# Out:
#   <div id="d58c2899-d6b1-4632-906a-7621bdc71b24" data-root-id="p1947" style="display: contents;"></div>
